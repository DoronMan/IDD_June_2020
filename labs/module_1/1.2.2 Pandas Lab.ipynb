# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
df = pd.read_csv("../../DATA/Employee-attrition.csv")

# %%
df.head()
# Out:
# pandas.core.frame.DataFrame

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# ...

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# 18

# %%
index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %%
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find Shape of Data Frame

# %%
data.shape
# Out:
# (49653, 18)

# %% [markdown]
# #### 1.B Find Data Tyeps of Data Frame

# %%
df.dtypes
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %% [markdown]
# #### 1.C Find Number of Data Types in a Data Frame
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %%
df.dtypes.value_counts()
# Out:
# object    13
# int64      5
# dtype: int64

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore difference.

# %%
#it shows diffrent columns of the dataframe raws/attributes (EmployeeID   recorddate_key ...)
df.info
# Out:
# <bound method DataFrame.info of        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Check Values of Job_Title column

# %%
df['job_title'].value_counts()
# Out:
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Bakery Manager                      285
# Meats Manager                       285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Accounts Receiveable Clerk           30
# Labor Relations Analyst              30
# Trainer                              26
# Accounts Payable Clerk               25
# Investment Analyst                   20
# Compensation Analyst                 20
# Systems Analyst                      20
# ...

# %% [markdown]
# #### 2.B Find How Many Rows Are in Each Job Title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
#df['job_title'].value_counts()
Mc_raws = (df['job_title'] == 'Meat Cutter').value_counts()
D_raws = (df['job_title'] == 'Dairy Person').value_counts()
PC = (df['job_title'] == 'Produce Clerk').value_counts()

print("Meat Cutter \t" + str(Mc_raws[1]) + "\t\n" + "Dairy Person\t" + str(D_raws[1]) +  "\t\n" + "Produce Clerk\t" + str(PC[1]) )
# Out:
# Meat Cutter 	9984
# Dairy Person	8590
# Produce Clerk	8237

# %%
#### 2.C [BONUS] Write A Function to Row Count




def row_count(column_name):
    number_of_rows = df.loc[:, column_name].count()
    return number_of_rows

# %%
row_count('age')
# Out:
# 49653

# %% [markdown]
# #### 2.D Describe 'Age'
#
# Find count,  mean,  std, min, max of column 'age'

# %%
df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %%
print(df['age'].count())
print(df['age'].mean())
print(df['age'].min())
print(df['age'].max())
# Out:
# 49653
# 42.077034620264634
# 19
# 65

# %% [markdown]
# ##### 2.E [BONUS] Describe 'All Numeric Columns of Data Frame
#
# Find count, mean, std, min, max of of all columns of dataframe

# %%
###trying to print only numeric datatypes

x = df.select_dtypes(include=['int64'])
x.describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %%
####Logic of for loop explanation please ????

count = 0
df_new.reindex_like(df)
for i in  df.dtypes == 'int64': 
    if i == True :
        #print(df[count:count + 1])
        df_new = df_new + df[count:count + 1]
        print(df.iloc[count:, count + 1].dtypes)
        count = count + 1
    else :
        #print("i" , i , "\n")
        count = count + 1
        
#df_new.dtypes
# Out:
# object
# int64
# object
# object
# object

# %%
df.count()
# Out:
# EmployeeID             49653
# recorddate_key         49653
# birthdate_key          49653
# orighiredate_key       49653
# terminationdate_key    49653
# age                    49653
# length_of_service      49653
# city_name              49653
# department_name        49653
# job_title              49653
# store_name             49653
# gender_short           49653
# gender_full            49653
# termreason_desc        49653
# termtype_desc          49653
# STATUS_YEAR            49653
# STATUS                 49653
# BUSINESS_UNIT          49653
# dtype: int64

# %%
df.max()
# Out:
# EmployeeID                      8336
# recorddate_key         9/1/2015 0:00
# birthdate_key               9/9/1994
# orighiredate_key            9/9/2012
# terminationdate_key         9/9/2010
# age                               65
# length_of_service                 26
# city_name              Williams Lake
# department_name             Training
# job_title                  VP Stores
# store_name                        46
# gender_short                       M
# gender_full                     Male
# termreason_desc           Retirement
# termtype_desc              Voluntary
# STATUS_YEAR                     2015
# STATUS                    TERMINATED
# BUSINESS_UNIT                 STORES
# dtype: object

# %%
# 3. Making The Index Meaningful
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
# ...

# %%
# A:

# %% [markdown]
# #### 3.A Find A Specifc Row Using Index

# %%
df[5:6]
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 5            1/1/1900   57                 22  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 5       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 5  Not Applicable         2011  ACTIVE    HEADOFFICE

# %% [markdown]
# #### 3.B Sort Data Frame using Index

# %%
 df.sort_index()
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %% [markdown]
# #### 3.C [BONUS] Sort Data Frame using Age

# %%
 df.sort_values('age',ascending=True)
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 48132        8325  12/31/2013 0:00     12/7/1994       11/29/2013
# 47925        8253  12/31/2013 0:00     5/15/1994        8/12/2013
# 47922        8252  12/31/2013 0:00     5/10/1994         8/9/2013
# 47919        8251  12/31/2013 0:00      5/7/1994         8/7/2013
# 47916        8250  12/31/2013 0:00     4/26/1994         8/2/2013
# ...           ...              ...           ...              ...
# 48635        3262    8/1/2008 0:00     8/23/1943        2/28/1995
# 48634        3248    8/1/2008 0:00     8/14/1943        2/19/1995
# 49127        4948    7/1/2013 0:00      7/9/1948        1/14/2000
# 48651        3356   11/1/2008 0:00    11/18/1943        5/26/1995
# 48820        4138    2/1/2011 0:00     2/12/1946        8/20/1997
#
#       terminationdate_key  age  length_of_service        city_name  \
# 48132            1/1/1900   19                  0        Cranbrook
# ...

# %% [markdown]
# #### 3.D [BONUS] Using Sample Select Any Row

# %%
df.sample(1)
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 36399        6363  12/31/2011 0:00     9/23/1979       11/18/2005
#
#       terminationdate_key  age  length_of_service city_name department_name  \
# 36399            1/1/1900   32                  6  Victoria          Bakery
#
#       job_title  store_name gender_short gender_full termreason_desc  \
# 36399     Baker          46            M        Male  Not Applicable
#
#         termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 36399  Not Applicable         2011  ACTIVE        STORES

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find Rows Where Job_Title is CEO

# %%
df.loc[df['job_title'] == 'CEO']
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# ...

# %% [markdown]
# #### 4.B Group By Age

# %%
df.groupby('age').count()
# Out:
#      EmployeeID  recorddate_key  birthdate_key  orighiredate_key  \
# age
# 19          158             158            158               158
# 20          408             408            408               408
# 21          703             703            703               703
# 22          815             815            815               815
# 23          960             960            960               960
# 24         1111            1111           1111              1111
# 25         1197            1197           1197              1197
# 26         1210            1210           1210              1210
# 27         1235            1235           1235              1235
# 28         1225            1225           1225              1225
# 29         1227            1227           1227              1227
# 30         1212            1212           1212              1212
# 31         1146            1146           1146              1146
# ...

# %% [markdown]
# # 5. Visualization
#
# #### 5.A Plot Histogram of Age

# %%
#df_numpy = df['age'].to_numpy()
plt.xlabel('Age')
plt.ylabel('Age frequancy')
#print(type(df['age'].to_numpy()))

x = df['age'].to_numpy()


print(np.max(np.unique(x, return_counts=True)))
print(x.size)
#plt.ylim((0, x.size))
print(df['age'].max())
plt.hist(df['age'].to_numpy() , rwidth= 0.8, bins = 100)
# Out:
# 1235
# 49653
# 65
# (array([ 158.,    0.,  408.,    0.,  703.,    0.,  815.,    0.,  960.,
#            0., 1111.,    0.,    0., 1197.,    0., 1210.,    0., 1235.,
#            0., 1225.,    0., 1227.,    0., 1212.,    0.,    0., 1146.,
#            0., 1153.,    0., 1164.,    0., 1188.,    0., 1189.,    0.,
#         1176.,    0.,    0., 1149.,    0., 1156.,    0., 1142.,    0.,
#         1130.,    0., 1135.,    0.,    0., 1152.,    0., 1150.,    0.,
#         1157.,    0., 1141.,    0., 1161.,    0., 1173.,    0.,    0.,
#         1180.,    0., 1196.,    0., 1218.,    0., 1207.,    0., 1188.,
#            0., 1188.,    0.,    0., 1159.,    0., 1168.,    0., 1154.,
#            0., 1130.,    0., 1130.,    0., 1128.,    0.,    0., 1109.,
#            0.,  757.,    0.,  712.,    0.,  667.,    0.,  646.,    0.,
#          593.]),
#  array([19.  , 19.46, 19.92, 20.38, 20.84, 21.3 , 21.76, 22.22, 22.68,
#         23.14, 23.6 , 24.06, 24.52, 24.98, 25.44, 25.9 , 26.36, 26.82,
# ...

# %% [markdown]
# #### 5.B BoxPlot of Age

# %%
plt.boxplot(df['age'].to_numpy())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe83fc14f90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe84365bed0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe83fc14490>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe843695250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe84368bdd0>],
#  'means': []}

# %% [markdown]
# #### 5.C Scatterplot of age and length_of_service

# %%
#
df_age_numpy = df['age'].to_numpy()
df_length_of_service_numpy = df['length_of_service'].to_numpy()

plt.xlabel('Age')
plt.ylabel('length_of_service')
plt.scatter(df_age_numpy, df_length_of_service_numpy)

# %%
df
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %%
df.loc[:,['age', 'birthdate_key']]
# Out:
#        age birthdate_key
# 0       52      1/3/1954
# 1       53      1/3/1954
# 2       54      1/3/1954
# 3       55      1/3/1954
# 4       56      1/3/1954
# ...    ...           ...
# 49648   21     5/28/1994
# 49649   19     6/13/1994
# 49650   21     7/18/1994
# 49651   19      9/2/1994
# 49652   20    11/28/1994
#
# [49653 rows x 2 columns]

# %%
df.iloc[:, [0, 1]]
# Out:
#        EmployeeID   recorddate_key
# 0            1318  12/31/2006 0:00
# 1            1318  12/31/2007 0:00
# 2            1318  12/31/2008 0:00
# 3            1318  12/31/2009 0:00
# 4            1318  12/31/2010 0:00
# ...           ...              ...
# 49648        8258   12/1/2015 0:00
# 49649        8264    8/1/2013 0:00
# 49650        8279   12/1/2015 0:00
# 49651        8296   12/1/2013 0:00
# 49652        8321   12/1/2014 0:00
#
# [49653 rows x 2 columns]

# %%
(df['age'] == 65).value_counts()
# Out:
# False    49060
# True       593
# Name: age, dtype: int64

# %%
df['age']
# Out:
# 0        52
# 1        53
# 2        54
# 3        55
# 4        56
#          ..
# 49648    21
# 49649    19
# 49650    21
# 49651    19
# 49652    20
# Name: age, Length: 49653, dtype: int64
